# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df_wide = pd.read_csv('data.csv')

df_wide.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.421063e+10  2.496398e+10  2.707880e+10  3.177575e+10
# 2  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.CD  1.190495e+10  1.270788e+10  1.363076e+10  1.446909e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2015          2016          2017  \
# 0           NaN           NaN  ...  2.962907e+09  2.983635e+09  3.092429e+09
# 1  3.028579e+10  3.381317e+10  ...  8.982778e+11  8.289428e+11  9.729989e+11
# 2           NaN           NaN  ...  1.913422e+10  1.811657e+10  1.875346e+10
# 3  1.580376e+10  1.692109e+10  ...  7.717669e+11  6.943610e+11  6.878492e+11
# 4           NaN           NaN  ...  9.049642e+10  5.276162e+10  7.369015e+10
#
#            2018          2019          2020          2021          2022  \
# 0  3.276184e+09  3.395799e+09  2.481857e+09  2.929447e+09  3.279344e+09
# 1  1.012306e+12  1.009721e+12  9.333918e+11  1.085745e+12  1.191423e+12
# 2  1.805322e+10  1.879944e+10  1.995593e+10  1.426000e+10  1.449724e+10
# 3  7.704950e+11  8.264838e+11  7.898017e+11  8.493124e+11  8.839739e+11
# 4  7.945069e+10  7.089796e+10  4.850156e+10  6.650513e+10  1.043997e+11
#
#            2023  2024
# 0  3.648573e+09   NaN
# 1  1.245472e+12   NaN
# 2  1.723305e+10   NaN
# 3  7.991060e+11   NaN
# 4  8.482465e+10   NaN
#
# [5 rows x 69 columns]

# %%
df_wide.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024'],
#       dtype='object')

# %%
df_wide.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2020              float64
# 2021              float64
# 2022              float64
# 2023              float64
# 2024              float64
# Length: 69, dtype: object

# %%
df_wide.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  1.510000e+02  1.540000e+02  1.570000e+02  1.570000e+02  1.570000e+02
# mean   6.786171e+10  6.982251e+10  7.327492e+10  7.908218e+10  8.680328e+10
# std    2.019254e+11  2.116016e+11  2.257269e+11  2.427310e+11  2.657976e+11
# min    1.201202e+07  1.159202e+07  1.254164e+07  1.283330e+07  1.341663e+07
# 25%    5.079241e+08  5.007338e+08  5.740911e+08  5.862949e+08  5.828164e+08
# 50%    3.359404e+09  3.330233e+09  3.308913e+09  3.988462e+09  4.016794e+09
# 75%    3.325071e+10  3.282977e+10  3.184162e+10  3.657288e+10  3.319881e+10
# max    1.371947e+12  1.445951e+12  1.550598e+12  1.669570e+12  1.830168e+12
#
#                1965          1966          1967          1968          1969  \
# count  1.630000e+02  1.640000e+02  1.670000e+02  1.680000e+02  1.680000e+02
# mean   9.133482e+10  9.793328e+10  1.014971e+11  1.086794e+11  1.203480e+11
# std    2.844773e+11  3.088386e+11  3.257876e+11  3.515860e+11  3.876032e+11
# min    1.359393e+07  1.446908e+07  1.583511e+07  1.460000e+07  1.585000e+07
# 25%    5.956572e+08  6.450667e+08  6.311234e+08  6.211906e+08  6.574670e+08
# 50%    3.817227e+09  4.153527e+09  3.532700e+09  4.529031e+09  5.087251e+09
# 75%    3.464910e+10  3.720117e+10  3.658090e+10  3.851340e+10  4.334334e+10
# max    1.994298e+12  2.161754e+12  2.293944e+12  2.478900e+12  2.738144e+12
#
#        ...          2015          2016          2017          2018  \
# count  ...  2.590000e+02  2.580000e+02  2.580000e+02  2.580000e+02
# mean   ...  2.382043e+12  2.424134e+12  2.597268e+12  2.765285e+12
# std    ...  8.174322e+12  8.328694e+12  8.865044e+12  9.440413e+12
# min    ...  3.681194e+07  4.162906e+07  4.527660e+07  4.801526e+07
# 25%    ...  8.766202e+09  8.620784e+09  9.193745e+09  9.928840e+09
# 50%    ...  4.871750e+10  4.806565e+10  5.277001e+10  5.609719e+10
# 75%    ...  4.973625e+11  5.042315e+11  5.341521e+11  5.491441e+11
# max    ...  7.547247e+13  7.670255e+13  8.171204e+13  8.688484e+13
#
#                2019          2020          2021          2022          2023  \
# count  2.580000e+02  2.570000e+02  2.570000e+02  2.540000e+02  2.420000e+02
# mean   2.807353e+12  2.736278e+12  3.141029e+12  3.307885e+12  3.618640e+12
# std    9.580867e+12  9.368340e+12  1.069643e+13  1.114471e+13  1.190401e+13
# min    5.412320e+07  5.174659e+07  6.019641e+07  5.906598e+07  6.228031e+07
# 25%    1.011166e+10  9.516738e+09  1.007135e+10  1.246361e+10  1.543170e+10
# 50%    5.775248e+10  5.366864e+10  6.152928e+10  6.970415e+10  8.383752e+10
# 75%    5.421641e+11  5.451476e+11  6.371869e+11  6.799031e+11  1.021922e+12
# max    8.814985e+13  8.576301e+13  9.784830e+13  1.017709e+14  1.061717e+14
#
#        2024
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN
#
# [8 rows x 65 columns]

# %%
df_wide[df_wide['Country Name'] == 'United States'].plot()

# %%
# Identify the columns to keep (id variables)
id_vars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']

# Identify the columns to melt (value variables - the years)
# Filter out any non-year columns that might be present after the id_vars
value_vars = [col for col in df_wide.columns if col not in id_vars]

# Melt the DataFrame from wide to long format
df_long = pd.melt(df_wide,
                  id_vars=id_vars,
                  value_vars=value_vars,
                  var_name='Year',
                  value_name='GDP (current US$)')

# %%
df_long.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code  Year  GDP (current US$)
# 0  NY.GDP.MKTP.CD  1960                NaN
# 1  NY.GDP.MKTP.CD  1960       2.421063e+10
# 2  NY.GDP.MKTP.CD  1960                NaN
# 3  NY.GDP.MKTP.CD  1960       1.190495e+10
# 4  NY.GDP.MKTP.CD  1960                NaN

# %%
df_long_usa = df_long[df_long['Country Name'] == 'United States']
df_long_usa['Country Code'].unique()
# Out:
# array(['USA'], dtype=object)

# %%
df_long[df_long['Country Name'] == 'United States'].plot()
# Out:
# <Axes: >

# %%
df_long_usa.groupby('Country Name')['GDP (current US$)'].pct_change() * 100
# Out:
# /tmp/ipykernel_7222/1573721347.py:1: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df_long_usa.groupby('Country Name')['GDP (current US$)'].pct_change() * 100
# 251            NaN
# 517       3.681207
# 783       7.420557
# 1049      5.536275
# 1315      7.391168
#            ...
# 16211    -0.862939
# 16477    10.897511
# 16743     9.820975
# 17009     6.589853
# 17275     0.000000
# Name: GDP (current US$), Length: 65, dtype: float64

# %%
# Convert 'Year' column to numeric (optional, but good practice)
# Errors='coerce' will turn any non-numeric years into NaN
df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce')

# Drop rows where 'Year' could not be converted to numeric (if any)
df_long.dropna(subset=['Year'], inplace=True)

# Convert Year to integer type
df_long['Year'] = df_long['Year'].astype(int)

# Display the first few rows of the long format DataFrame
print("Original Wide DataFrame shape:", df_wide.shape)
print("Converted Long DataFrame shape:", df_long.shape)
print("\nFirst 5 rows of the long format DataFrame:")
print(df_long.head())

# Display the last few rows to see recent years
print("\nLast 5 rows of the long format DataFrame:")
print(df_long.tail())

# You can now save this long format DataFrame if needed
# df_long.to_csv('data_long_format.csv', index=False)
# Out:
# Original Wide DataFrame shape: (266, 70)
# Converted Long DataFrame shape: (17290, 6)
#
# First 5 rows of the long format DataFrame:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code  Year  GDP (current US$)
# 0  NY.GDP.MKTP.CD  1960                NaN
# 1  NY.GDP.MKTP.CD  1960       2.421063e+10
# 2  NY.GDP.MKTP.CD  1960                NaN
# 3  NY.GDP.MKTP.CD  1960       1.190495e+10
# 4  NY.GDP.MKTP.CD  1960                NaN
#
# Last 5 rows of the long format DataFrame:
#        Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 17285        Kosovo          XKX  GDP (current US$)  NY.GDP.MKTP.CD  2024
# 17286   Yemen, Rep.          YEM  GDP (current US$)  NY.GDP.MKTP.CD  2024
# 17287  South Africa          ZAF  GDP (current US$)  NY.GDP.MKTP.CD  2024
# 17288        Zambia          ZMB  GDP (current US$)  NY.GDP.MKTP.CD  2024
# 17289      Zimbabwe          ZWE  GDP (current US$)  NY.GDP.MKTP.CD  2024
#
#        GDP (current US$)
# 17285                NaN
# 17286                NaN
# 17287                NaN
# 17288                NaN
# 17289                NaN

# %% [markdown]
# ## Manually Creating a Single Country Plot

# %%
country_name_single = 'United States'
df_country_single = df_long[df_long['Country Name'] == country_name_single].copy()

# %%
df_long.sort_values(by='Year', inplace=True)

# %%
df_long
# Out:
#                      Country Name Country Code     Indicator Name  \
# 217            Sub-Saharan Africa          SSF  GDP (current US$)
# 202            Russian Federation          RUS  GDP (current US$)
# 188                         Palau          PLW  GDP (current US$)
# 207                       Senegal          SEN  GDP (current US$)
# 84                      Gibraltar          GIB  GDP (current US$)
# ...                           ...          ...                ...
# 17083          Dominican Republic          DOM  GDP (current US$)
# 17205                OECD members          OED  GDP (current US$)
# 17086  Early-demographic dividend          EAR  GDP (current US$)
# 17257                    Thailand          THA  GDP (current US$)
# 17289                    Zimbabwe          ZWE  GDP (current US$)
#
#        Indicator Code  Year  GDP (current US$)
# 217    NY.GDP.MKTP.CD  1960       3.599988e+10
# 202    NY.GDP.MKTP.CD  1960                NaN
# 188    NY.GDP.MKTP.CD  1960                NaN
# 207    NY.GDP.MKTP.CD  1960       1.003692e+09
# 84     NY.GDP.MKTP.CD  1960                NaN
# ...               ...   ...                ...
# 17083  NY.GDP.MKTP.CD  2024                NaN
# 17205  NY.GDP.MKTP.CD  2024                NaN
# 17086  NY.GDP.MKTP.CD  2024                NaN
# 17257  NY.GDP.MKTP.CD  2024                NaN
# 17289  NY.GDP.MKTP.CD  2024                NaN
#
# [17290 rows x 6 columns]

# %%
df_country_single.isna().sum()
# Out:
# Country Name         0
# Country Code         0
# Indicator Name       0
# Indicator Code       0
# Year                 0
# GDP (current US$)    1
# dtype: int64

# %%
df_country_single[df_country_single.isna().any(axis=1)]
# Out:
#         Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 17275  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2024
#
#        GDP (current US$)
# 17275                NaN

# %%
df_country_single['Year'].unique()
# Out:
# array(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype=object)

# %%
df_country_single.dropna(subset=['GDP (current US$)'], inplace=True)
df_country_single.sort_values('Year', inplace=True)
plt.figure(figsize=(12, 6))
plt.plot(df_country_single['Year'], df_country_single['GDP (current US$)'], marker='o', linestyle='-', color='#7d0b78')
plt.title(f'GDP (current US$) Trend for {country_name_single}')
plt.xlabel('Year')
plt.ylabel('GDP (current US$)')
plt.grid(True)
years_single = df_country_single['Year'].unique()
if len(years_single) > 10:
    plt.xticks(years_single[::5], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparing GDP Trends of Multiple Countries

# %%
countries_to_compare = ['United States', 'China', 'Germany', 'Japan', 'India']
df_compare = df_long[df_long['Country Name'].isin(countries_to_compare)].copy()

# Drop rows with missing GDP values for the selected countries before plotting
df_compare.dropna(subset=['GDP (current US$)'], inplace=True)

# Sort by country and year for consistent plotting
df_compare.sort_values(['Country Name', 'Year'], inplace=True)

# Create the plot
plt.figure(figsize=(14, 7)) # Adjust figure size

# Plot GDP trend for each country
for country in countries_to_compare:
    df_subset = df_compare[df_compare['Country Name'] == country]
    plt.plot(df_subset['Year'], df_subset['GDP (current US$)'], marker='.', linestyle='-', label=country) # Smaller marker

# Add titles and labels
plt.title('GDP (current US$) Comparison for Selected Countries')
plt.xlabel('Year')
plt.ylabel('GDP (current US$)')
plt.legend() # Add legend to identify countries
plt.grid(True) # Add a grid

# Improve x-axis labels - find common range or use representative ticks
all_years = df_compare['Year'].unique()
all_years.sort()
if len(all_years) > 10:
     # Show fewer ticks if range is large, e.g., every 5 or 10 years
     tick_frequency = 5 if len(all_years) <= 60 else 10
     plt.xticks(all_years[::tick_frequency], rotation=45)
else:
    plt.xticks(rotation=45) # Rotate labels if fewer years

plt.tight_layout() # Adjust layout
plt.show() # Display the plot

# %% [markdown]
# ## Plot 3: Bar Chart Comparison for the Most Recent Year

# %%
# Find the most recent year available for each country in the comparison set
latest_years = df_compare.loc[df_compare.groupby('Country Name')['Year'].idxmax()]

# Sort by GDP for better visualization
latest_years = latest_years.sort_values('GDP (current US$)', ascending=False)

# Create the bar chart
plt.figure(figsize=(12, 6))
plt.bar(latest_years['Country Name'], latest_years['GDP (current US$)'], color='skyblue')

# Add titles and labels
plt.title(f'GDP (current US$) Comparison for Selected Countries (Latest Available Year)')
plt.xlabel('Country')
plt.ylabel('GDP (current US$)')
plt.xticks(rotation=45, ha='right') # Rotate country names for readability
plt.grid(axis='y', linestyle='--') # Add horizontal grid lines

# Add value labels on top of bars (optional, can be cluttered)
for index, value in enumerate(latest_years['GDP (current US$)']):
    plt.text(index, value, f'{value:,.0f}', ha='center', va='bottom')

plt.tight_layout() # Adjust layout
plt.show() # Display the plot

# %% [markdown]
# ## Plot 4: GDP Growth Rate Comparison

# %%
df_compare.groupby('Country Name')['GDP (current US$)'].max()
# Out:
# Country Name
# China            1.788178e+13
# Germany          4.525704e+12
# India            3.567552e+12
# Japan            6.272363e+12
# United States    2.772071e+13
# Name: GDP (current US$), dtype: float64

# %%
df_compare['GDP Growth Rate (%)'] = df_compare.groupby('Country Name')['GDP (current US$)'].pct_change() * 100
df_compare
# Out:
#         Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 40             China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 306            China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1961
# 572            China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1962
# 838            China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1963
# 1104           China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1964
# ...              ...          ...                ...             ...   ...
# 15945  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2019
# 16211  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2020
# 16477  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2021
# 16743  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2022
# 17009  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2023
#
#        GDP (current US$)  GDP Growth Rate (%)
# 40          5.971625e+10                  NaN
# 306         5.005669e+10           -16.175770
# 572         4.720919e+10            -5.688550
# 838         5.070661e+10             7.408363
# 1104        5.970813e+10            17.752143
# ...                  ...                  ...
# 15945       2.153998e+13             4.276936
# 16211       2.135410e+13            -0.862939
# 16477       2.368117e+13            10.897511
# 16743       2.600689e+13             9.820975
# 17009       2.772071e+13             6.589853
#
# [320 rows x 7 columns]

# %%
# Calculate Year-over-Year GDP Growth Rate (%)
# Ensure data is sorted by Country then Year for correct pct_change calculation
df_compare.sort_values(['Country Name', 'Year'], inplace=True)
# Calculate pct_change within each group (country)
df_compare['GDP Growth Rate (%)'] = df_compare.groupby('Country Name')['GDP (current US$)'].pct_change() * 100

# Create the growth rate plot
plt.figure(figsize=(14, 7))

# Plot growth rate for each country
for country in countries_to_compare:
    df_subset = df_compare[df_compare['Country Name'] == country]
    # Plotting without the first year (NaN growth rate)
    plt.plot(df_subset['Year'][1:], df_subset['GDP Growth Rate (%)'][1:], marker='.', linestyle='-', label=country)

# Add titles and labels
plt.title('Annual GDP Growth Rate (%) Comparison for Selected Countries')
plt.xlabel('Year')
plt.ylabel('GDP Growth Rate (%)')
plt.axhline(0, color='red', linestyle='--', linewidth=0.8) # Add a line at 0% growth
plt.legend() # Add legend
plt.grid(True) # Add a grid

# Improve x-axis labels
# Using the same logic as Plot 2
if len(all_years) > 10:
     tick_frequency = 5 if len(all_years) <= 60 else 10
     plt.xticks(all_years[::tick_frequency], rotation=45)
else:
    plt.xticks(rotation=45)

plt.tight_layout() # Adjust layout
plt.show() # Display the plot

# %% [markdown]
# ## Box Plot of GDP Growth Rates for Selected Countries

# %%
# Prepare data for box plot - need growth rates per country
# Use df_compare which already has 'GDP Growth Rate (%)' calculated
# Drop NaN values which occur for the first year of data for each country
df_growth_box = df_compare.dropna(subset=['GDP Growth Rate (%)']).copy()

# Create the box plot
plt.figure(figsize=(12, 7))

# We need to group data by country to create the box plot correctly
# Matplotlib's boxplot can take a list of arrays/Series, one for each box
growth_data_to_plot = [df_growth_box[df_growth_box['Country Name'] == country]['GDP Growth Rate (%)']
                       for country in countries_to_compare]

plt.boxplot(growth_data_to_plot, labels=countries_to_compare, patch_artist=True, showfliers=False) # patch_artist for fill, showfliers=False to hide outliers for cleaner look

# Add titles and labels
plt.title('Distribution of Annual GDP Growth Rates (%) for Selected Countries (Full Period)')
plt.xlabel('Country')
plt.ylabel('GDP Growth Rate (%)')
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8) # Line at 0% growth
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--')

plt.tight_layout() # Adjust layout
plt.show() # Display the plot
# Out:
# /tmp/ipykernel_7222/1285502054.py:14: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(growth_data_to_plot, labels=countries_to_compare, patch_artist=True, showfliers=False) # patch_artist for fill, showfliers=False to hide outliers for cleaner look

# %% [markdown]
# ## Correlation Analysis between Countries' GDPs

# %%
df_compare
# Out:
#         Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 40             China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 306            China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1961
# 572            China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1962
# 838            China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1963
# 1104           China          CHN  GDP (current US$)  NY.GDP.MKTP.CD  1964
# ...              ...          ...                ...             ...   ...
# 15945  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2019
# 16211  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2020
# 16477  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2021
# 16743  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2022
# 17009  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2023
#
#        GDP (current US$)  GDP Growth Rate (%)
# 40          5.971625e+10                  NaN
# 306         5.005669e+10           -16.175770
# 572         4.720919e+10            -5.688550
# 838         5.070661e+10             7.408363
# 1104        5.970813e+10            17.752143
# ...                  ...                  ...
# 15945       2.153998e+13             4.276936
# 16211       2.135410e+13            -0.862939
# 16477       2.368117e+13            10.897511
# 16743       2.600689e+13             9.820975
# 17009       2.772071e+13             6.589853
#
# [320 rows x 7 columns]

# %%
gdp_pivot = df_compare.pivot(index='Year', columns='Country Name', values='GDP (current US$)')
gdp_pivot
# Out:
# Country Name         China       Germany         India         Japan  \
# Year
# 1960          5.971625e+10  8.461985e+10  3.702988e+10  4.741924e+10
# 1961          5.005669e+10  9.655820e+10  3.923244e+10  5.726676e+10
# 1962          4.720919e+10  1.058954e+11  4.216148e+10  6.498786e+10
# 1963          5.070661e+10  1.122325e+11  4.842192e+10  7.437928e+10
# 1964          5.970813e+10  1.233304e+11  5.648029e+10  8.749059e+10
# ...                    ...           ...           ...           ...
# 2019          1.427997e+13  3.957208e+12  2.835606e+12  5.117994e+12
# 2020          1.468774e+13  3.940143e+12  2.674852e+12  5.055587e+12
# 2021          1.782046e+13  4.348297e+12  3.167271e+12  5.034621e+12
# 2022          1.788178e+13  4.163596e+12  3.353470e+12  4.256411e+12
# 2023          1.779478e+13  4.525704e+12  3.567552e+12  4.204495e+12
#
# Country Name  United States
# Year
# 1960           5.419886e+11
# 1961           5.619403e+11
# 1962           6.036394e+11
# 1963           6.370586e+11
# 1964           6.841446e+11
# ...                     ...
# 2019           2.153998e+13
# 2020           2.135410e+13
# 2021           2.368117e+13
# 2022           2.600689e+13
# 2023           2.772071e+13
#
# [64 rows x 5 columns]

# %%
# Create a pivot table of GDP by Country and Year
gdp_pivot = df_compare.pivot(index='Year', columns='Country Name', values='GDP (current US$)')

# Calculate correlation between countries' GDPs
correlation_matrix = gdp_pivot.corr()
print("GDP Correlation Matrix:")
print(correlation_matrix)

# Visualize correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt=".2f")
plt.title('GDP Correlation Matrix Between Countries')
plt.tight_layout()
plt.show()
# Out:
# GDP Correlation Matrix:
# Country Name      China   Germany     India     Japan  United States
# Country Name
# China          1.000000  0.816361  0.990159  0.575539       0.914965
# Germany        0.816361  1.000000  0.873988  0.922899       0.964959
# India          0.990159  0.873988  1.000000  0.655225       0.953026
# Japan          0.575539  0.922899  0.655225  1.000000       0.826190
# United States  0.914965  0.964959  0.953026  0.826190       1.000000

# %% [markdown]
# ## Relative GDP Analysis

# %%
# Add a total GDP column (sum of all countries in our analysis) for each year
years_to_analyze = df_compare['Year'].unique()
for year in years_to_analyze:
    year_data = df_compare[df_compare['Year'] == year]
    total_gdp = year_data['GDP (current US$)'].sum()
    df_compare.loc[df_compare['Year'] == year, 'Total GDP'] = total_gdp

# Calculate each country's GDP as percentage of total
df_compare['GDP Share (%)'] = (df_compare['GDP (current US$)'] / df_compare['Total GDP']) * 100

# Visualize how the share has changed over time
plt.figure(figsize=(14, 7))
for country in countries_to_compare:
    country_data = df_compare[df_compare['Country Name'] == country]
    plt.plot(country_data['Year'], country_data['GDP Share (%)'], 
             marker='.', linestyle='-', label=country)

plt.title('Share of Total GDP by Country')
plt.xlabel('Year')
plt.ylabel('Percentage of Total GDP (%)')
plt.xticks(rotation=45, ha='right')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## BONUS: Linear Regression

# %%
df_long_usa
# Out:
#         Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 251    United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 517    United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  1961
# 783    United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  1962
# 1049   United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  1963
# 1315   United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  1964
# ...              ...          ...                ...             ...   ...
# 16211  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2020
# 16477  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2021
# 16743  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2022
# 17009  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2023
# 17275  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD  2024
#
#        GDP (current US$)
# 251         5.419886e+11
# 517         5.619403e+11
# 783         6.036394e+11
# 1049        6.370586e+11
# 1315        6.841446e+11
# ...                  ...
# 16211       2.135410e+13
# 16477       2.368117e+13
# 16743       2.600689e+13
# 17009       2.772071e+13
# 17275                NaN
#
# [65 rows x 6 columns]

# %%
df_long_usa.to_csv('long_usa.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import seaborn as sns

# Reading the CSV data
data = pd.read_csv('long_usa.csv')

# Preparing the data for regression analysis
data = data.dropna(subset=['GDP (current US$)'])
X = data['Year'].values.reshape(-1, 1)  # Independent variable: Year
y = data['GDP (current US$)'].values    # Dependent variable: GDP

# Fitting the linear regression model
model = LinearRegression()
model.fit(X, y)

# Extracting model coefficients
slope = model.coef_[0]
intercept = model.intercept_
r2 = model.score(X, y)

# Making predictions with the model
y_pred = model.predict(X)

# Predicting GDP for 2024 and 2025
future_years = np.array([[2024], [2025]])
future_gdp_predictions = model.predict(future_years)

# Creating a dataframe with the predicted values
future_df = pd.DataFrame({
    'Year': [2024, 2025],
    'Predicted GDP (current US$)': future_gdp_predictions
})

print(f"Linear Regression Model Results:")
print(f"Slope (coefficient): {slope:,.2f}")
print(f"Intercept: {intercept:,.2f}")
print(f"R-squared: {r2:.4f}")
print("\nGDP Predictions:")
print(future_df.to_string(index=False))

# Visualizing the data and the regression line
plt.figure(figsize=(12, 8))
sns.set_style('whitegrid')

# Plot actual data points
plt.scatter(X, y, color='blue', alpha=0.5, label='Actual GDP')

# Plot regression line
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression Line')

# Plot future predictions
plt.scatter(future_years, future_gdp_predictions, color='green', s=100, label='2024-2025 Predictions')

# Adding labels and title
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP (current US$)', fontsize=12)
plt.title('US GDP Linear Regression (1960-2023) with Future Predictions', fontsize=14)
plt.legend()
plt.grid(True)

# Format y-axis to show numbers in trillions
plt.ticklabel_format(style='plain', axis='y')
yticks = plt.yticks()[0]
plt.yticks(yticks, [f'${y/1e12:.1f}T' for y in yticks])

# Annotate the predicted values
for i, year in enumerate(future_years.flatten()):
    plt.annotate(f'${future_gdp_predictions[i]/1e12:.2f}T',
                 (year, future_gdp_predictions[i]),
                 textcoords="offset points",
                 xytext=(0,10),
                 ha='center')

plt.tight_layout()
plt.show()
# Out:
# Linear Regression Model Results:
# Slope (coefficient): 383,943,360,309.30
# Intercept: -756,074,969,832,377.62
# R-squared: 0.9198
#
# GDP Predictions:
#  Year  Predicted GDP (current US$)
#  2024                 2.102639e+13
#  2025                 2.141033e+13
